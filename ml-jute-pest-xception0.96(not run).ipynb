# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm
from PIL import Image
from torchvision import models, transforms
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, Dataset, random_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import time
from sklearn.metrics import f1_score
import timm

# %%
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/jutepest/sample_submission.csv
# /kaggle/input/jutepest/train.csv
# /kaggle/input/jutepest/test.csv
# /kaggle/input/jutepest/train_images/data_2198.jpg
# /kaggle/input/jutepest/train_images/data_4627.jpg
# /kaggle/input/jutepest/train_images/data_4335.jpg
# /kaggle/input/jutepest/train_images/data_3267.jpg
# /kaggle/input/jutepest/train_images/data_6807.jpg
# /kaggle/input/jutepest/train_images/data_5147.jpg
# /kaggle/input/jutepest/train_images/data_4768.jpg
# /kaggle/input/jutepest/train_images/data_3090.jpg
# /kaggle/input/jutepest/train_images/data_2961.jpg
# /kaggle/input/jutepest/train_images/data_4147.jpg
# /kaggle/input/jutepest/train_images/data_548.jpg
# /kaggle/input/jutepest/train_images/data_2240.jpg
# /kaggle/input/jutepest/train_images/data_1699.jpg
# /kaggle/input/jutepest/train_images/data_2939.jpg
# /kaggle/input/jutepest/train_images/data_4276.jpg
# /kaggle/input/jutepest/train_images/data_2919.jpg
# /kaggle/input/jutepest/train_images/data_3086.jpg
# /kaggle/input/jutepest/train_images/data_6079.jpg
# /kaggle/input/jutepest/train_images/data_7225.jpg
# /kaggle/input/jutepest/train_images/data_5364.jpg
# /kaggle/input/jutepest/train_images/data_1692.jpg
# /kaggle/input/jutepest/train_images/data_2434.jpg
# /kaggle/input/jutepest/train_images/data_4122.jpg
# /kaggle/input/jutepest/train_images/data_1561.jpg
# /kaggle/input/jutepest/train_images/data_6573.jpg
# /kaggle/input/jutepest/train_images/data_5664.jpg
# /kaggle/input/jutepest/train_images/data_5701.jpg
# /kaggle/input/jutepest/train_images/data_1739.jpg
# /kaggle/input/jutepest/train_images/data_3923.jpg
# /kaggle/input/jutepest/train_images/data_5947.jpg
# /kaggle/input/jutepest/train_images/data_5566.jpg
# /kaggle/input/jutepest/train_images/data_2356.jpg
# /kaggle/input/jutepest/train_images/data_4187.jpg
# /kaggle/input/jutepest/train_images/data_3316.jpg
# /kaggle/input/jutepest/train_images/data_6470.jpg
# /kaggle/input/jutepest/train_images/data_4260.jpg
# /kaggle/input/jutepest/train_images/data_1542.jpg
# /kaggle/input/jutepest/train_images/data_2175.jpg
# /kaggle/input/jutepest/train_images/data_5021.jpg
# /kaggle/input/jutepest/train_images/data_747.jpg
# /kaggle/input/jutepest/train_images/data_705.jpg
# /kaggle/input/jutepest/train_images/data_5369.jpg
# /kaggle/input/jutepest/train_images/data_1044.jpg
# /kaggle/input/jutepest/train_images/data_2249.jpg
# /kaggle/input/jutepest/train_images/data_1294.jpg
# /kaggle/input/jutepest/train_images/data_2925.jpg
# /kaggle/input/jutepest/train_images/data_6878.jpg
# /kaggle/input/jutepest/train_images/data_7208.jpg
# /kaggle/input/jutepest/train_images/data_1799.jpg
# /kaggle/input/jutepest/train_images/data_1568.jpg
# /kaggle/input/jutepest/train_images/data_7127.jpg
# /kaggle/input/jutepest/train_images/data_5171.jpg
# /kaggle/input/jutepest/train_images/data_6701.jpg
# /kaggle/input/jutepest/train_images/data_119.jpg
# /kaggle/input/jutepest/train_images/data_2043.jpg
# /kaggle/input/jutepest/train_images/data_3951.jpg
# /kaggle/input/jutepest/train_images/data_4963.jpg
# /kaggle/input/jutepest/train_images/data_6354.jpg
# /kaggle/input/jutepest/train_images/data_6189.jpg
# /kaggle/input/jutepest/train_images/data_4680.jpg
# /kaggle/input/jutepest/train_images/data_5315.jpg
# /kaggle/input/jutepest/train_images/data_6028.jpg
# /kaggle/input/jutepest/train_images/data_5150.jpg
# /kaggle/input/jutepest/train_images/data_7108.jpg
# /kaggle/input/jutepest/train_images/data_1276.jpg
# /kaggle/input/jutepest/train_images/data_229.jpg
# /kaggle/input/jutepest/train_images/data_6570.jpg
# /kaggle/input/jutepest/train_images/data_2186.jpg
# /kaggle/input/jutepest/train_images/data_5614.jpg
# /kaggle/input/jutepest/train_images/data_4711.jpg
# /kaggle/input/jutepest/train_images/data_5129.jpg
# /kaggle/input/jutepest/train_images/data_6658.jpg
# /kaggle/input/jutepest/train_images/data_6315.jpg
# /kaggle/input/jutepest/train_images/data_3280.jpg
# /kaggle/input/jutepest/train_images/data_5415.jpg
# /kaggle/input/jutepest/train_images/data_1277.jpg
# /kaggle/input/jutepest/train_images/data_865.jpg
# /kaggle/input/jutepest/train_images/data_2655.jpg
# /kaggle/input/jutepest/train_images/data_1472.jpg
# /kaggle/input/jutepest/train_images/data_5006.jpg
# /kaggle/input/jutepest/train_images/data_6295.jpg
# /kaggle/input/jutepest/train_images/data_5596.jpg
# /kaggle/input/jutepest/train_images/data_4529.jpg
# /kaggle/input/jutepest/train_images/data_4734.jpg
# /kaggle/input/jutepest/train_images/data_810.jpg
# /kaggle/input/jutepest/train_images/data_2361.jpg
# /kaggle/input/jutepest/train_images/data_4890.jpg
# /kaggle/input/jutepest/train_images/data_5867.jpg
# /kaggle/input/jutepest/train_images/data_4444.jpg
# /kaggle/input/jutepest/train_images/data_3305.jpg
# /kaggle/input/jutepest/train_images/data_3742.jpg
# /kaggle/input/jutepest/train_images/data_6111.jpg
# /kaggle/input/jutepest/train_images/data_5220.jpg
# /kaggle/input/jutepest/train_images/data_1195.jpg
# /kaggle/input/jutepest/train_images/data_4306.jpg
# /kaggle/input/jutepest/train_images/data_5972.jpg
# /kaggle/input/jutepest/train_images/data_2408.jpg
# /kaggle/input/jutepest/train_images/data_390.jpg
# /kaggle/input/jutepest/train_images/data_6998.jpg
# /kaggle/input/jutepest/train_images/data_1492.jpg
# /kaggle/input/jutepest/train_images/data_2755.jpg
# /kaggle/input/jutepest/train_images/data_5952.jpg
# /kaggle/input/jutepest/train_images/data_2036.jpg
# /kaggle/input/jutepest/train_images/data_2760.jpg
# /kaggle/input/jutepest/train_images/data_4426.jpg
# /kaggle/input/jutepest/train_images/data_3468.jpg
# /kaggle/input/jutepest/train_images/data_464.jpg
# /kaggle/input/jutepest/train_images/data_5069.jpg
# /kaggle/input/jutepest/train_images/data_4134.jpg
# /kaggle/input/jutepest/train_images/data_6970.jpg
# /kaggle/input/jutepest/train_images/data_6420.jpg
# /kaggle/input/jutepest/train_images/data_5882.jpg
# /kaggle/input/jutepest/train_images/data_3384.jpg
# /kaggle/input/jutepest/train_images/data_3651.jpg
# /kaggle/input/jutepest/train_images/data_5823.jpg
# /kaggle/input/jutepest/train_images/data_6157.jpg
# /kaggle/input/jutepest/train_images/data_2528.jpg
# /kaggle/input/jutepest/train_images/data_4839.jpg
# /kaggle/input/jutepest/train_images/data_4143.jpg
# /kaggle/input/jutepest/train_images/data_975.jpg
# /kaggle/input/jutepest/train_images/data_4046.jpg
# /kaggle/input/jutepest/train_images/data_6766.jpg
# /kaggle/input/jutepest/train_images/data_5217.jpg
# /kaggle/input/jutepest/train_images/data_2914.jpg
# /kaggle/input/jutepest/train_images/data_1920.jpg
# /kaggle/input/jutepest/train_images/data_2888.jpg
# /kaggle/input/jutepest/train_images/data_6531.jpg
# /kaggle/input/jutepest/train_images/data_3174.jpg
# /kaggle/input/jutepest/train_images/data_6557.jpg
# /kaggle/input/jutepest/train_images/data_5546.jpg
# /kaggle/input/jutepest/train_images/data_7086.jpg
# /kaggle/input/jutepest/train_images/data_4308.jpg
# /kaggle/input/jutepest/train_images/data_2734.jpg
# /kaggle/input/jutepest/train_images/data_3821.jpg
# /kaggle/input/jutepest/train_images/data_3905.jpg
# /kaggle/input/jutepest/train_images/data_2713.jpg
# /kaggle/input/jutepest/train_images/data_6318.jpg
# /kaggle/input/jutepest/train_images/data_7140.jpg
# /kaggle/input/jutepest/train_images/data_4548.jpg
# /kaggle/input/jutepest/train_images/data_356.jpg
# /kaggle/input/jutepest/train_images/data_5902.jpg
# /kaggle/input/jutepest/train_images/data_2366.jpg
# /kaggle/input/jutepest/train_images/data_4213.jpg
# /kaggle/input/jutepest/train_images/data_1447.jpg
# /kaggle/input/jutepest/train_images/data_7031.jpg
# /kaggle/input/jutepest/train_images/data_5004.jpg
# /kaggle/input/jutepest/train_images/data_4228.jpg
# /kaggle/input/jutepest/train_images/data_2305.jpg
# /kaggle/input/jutepest/train_images/data_3133.jpg
# /kaggle/input/jutepest/train_images/data_1451.jpg
# /kaggle/input/jutepest/train_images/data_5331.jpg
# /kaggle/input/jutepest/train_images/data_1780.jpg
# /kaggle/input/jutepest/train_images/data_6853.jpg
# /kaggle/input/jutepest/train_images/data_4247.jpg
# /kaggle/input/jutepest/train_images/data_4096.jpg
# /kaggle/input/jutepest/train_images/data_6974.jpg
# /kaggle/input/jutepest/train_images/data_3967.jpg
# /kaggle/input/jutepest/train_images/data_828.jpg
# /kaggle/input/jutepest/train_images/data_6519.jpg
# /kaggle/input/jutepest/train_images/data_1672.jpg
# /kaggle/input/jutepest/train_images/data_3982.jpg
# /kaggle/input/jutepest/train_images/data_3152.jpg
# /kaggle/input/jutepest/train_images/data_5119.jpg
# /kaggle/input/jutepest/train_images/data_3014.jpg
# /kaggle/input/jutepest/train_images/data_6389.jpg
# /kaggle/input/jutepest/train_images/data_7117.jpg
# /kaggle/input/jutepest/train_images/data_6084.jpg
# /kaggle/input/jutepest/train_images/data_2974.jpg
# /kaggle/input/jutepest/train_images/data_4408.jpg
# /kaggle/input/jutepest/train_images/data_753.jpg
# /kaggle/input/jutepest/train_images/data_4432.jpg
# /kaggle/input/jutepest/train_images/data_3357.jpg
# /kaggle/input/jutepest/train_images/data_4612.jpg
# /kaggle/input/jutepest/train_images/data_5714.jpg
# /kaggle/input/jutepest/train_images/data_3560.jpg
# /kaggle/input/jutepest/train_images/data_6193.jpg
# /kaggle/input/jutepest/train_images/data_3380.jpg
# /kaggle/input/jutepest/train_images/data_5753.jpg
# /kaggle/input/jutepest/train_images/data_2389.jpg
# /kaggle/input/jutepest/train_images/data_6336.jpg
# /kaggle/input/jutepest/train_images/data_1572.jpg
# /kaggle/input/jutepest/train_images/data_7026.jpg
# /kaggle/input/jutepest/train_images/data_186.jpg
# /kaggle/input/jutepest/train_images/data_4658.jpg
# /kaggle/input/jutepest/train_images/data_4723.jpg
# /kaggle/input/jutepest/train_images/data_5498.jpg
# /kaggle/input/jutepest/train_images/data_6848.jpg
# /kaggle/input/jutepest/train_images/data_5456.jpg
# /kaggle/input/jutepest/train_images/data_4224.jpg
# /kaggle/input/jutepest/train_images/data_5852.jpg
# /kaggle/input/jutepest/train_images/data_6860.jpg
# /kaggle/input/jutepest/train_images/data_4509.jpg
# /kaggle/input/jutepest/train_images/data_1755.jpg
# /kaggle/input/jutepest/train_images/data_4316.jpg
# /kaggle/input/jutepest/train_images/data_326.jpg
# /kaggle/input/jutepest/train_images/data_2326.jpg
# /kaggle/input/jutepest/train_images/data_2001.jpg
# /kaggle/input/jutepest/train_images/data_3129.jpg
# /kaggle/input/jutepest/train_images/data_3561.jpg
# /kaggle/input/jutepest/train_images/data_2811.jpg
# /kaggle/input/jutepest/train_images/data_85.jpg
# /kaggle/input/jutepest/train_images/data_6623.jpg
# /kaggle/input/jutepest/train_images/data_152.jpg
# /kaggle/input/jutepest/train_images/data_3051.jpg
# /kaggle/input/jutepest/train_images/data_2916.jpg
# /kaggle/input/jutepest/train_images/data_2120.jpg
# /kaggle/input/jutepest/train_images/data_2871.jpg
# /kaggle/input/jutepest/train_images/data_1325.jpg
# /kaggle/input/jutepest/train_images/data_1063.jpg
# /kaggle/input/jutepest/train_images/data_6366.jpg
# /kaggle/input/jutepest/train_images/data_4073.jpg
# /kaggle/input/jutepest/train_images/data_5297.jpg
# /kaggle/input/jutepest/train_images/data_2373.jpg
# /kaggle/input/jutepest/train_images/data_6714.jpg
# /kaggle/input/jutepest/train_images/data_3608.jpg
# /kaggle/input/jutepest/train_images/data_5199.jpg
# /kaggle/input/jutepest/train_images/data_4676.jpg
# /kaggle/input/jutepest/train_images/data_3828.jpg
# /kaggle/input/jutepest/train_images/data_260.jpg
# /kaggle/input/jutepest/train_images/data_1206.jpg
# /kaggle/input/jutepest/train_images/data_4914.jpg
# /kaggle/input/jutepest/train_images/data_1001.jpg
# /kaggle/input/jutepest/train_images/data_4608.jpg
# /kaggle/input/jutepest/train_images/data_7120.jpg
# /kaggle/input/jutepest/train_images/data_5646.jpg
# /kaggle/input/jutepest/train_images/data_6427.jpg
# /kaggle/input/jutepest/train_images/data_6927.jpg
# /kaggle/input/jutepest/train_images/data_2109.jpg
# /kaggle/input/jutepest/train_images/data_473.jpg
# /kaggle/input/jutepest/train_images/data_1518.jpg
# /kaggle/input/jutepest/train_images/data_4326.jpg
# /kaggle/input/jutepest/train_images/data_1466.jpg
# /kaggle/input/jutepest/train_images/data_963.jpg
# /kaggle/input/jutepest/train_images/data_5550.jpg
# /kaggle/input/jutepest/train_images/data_4136.jpg
# /kaggle/input/jutepest/train_images/data_4351.jpg
# /kaggle/input/jutepest/train_images/data_6699.jpeg
# /kaggle/input/jutepest/train_images/data_3472.jpg
# /kaggle/input/jutepest/train_images/data_7085.jpg
# /kaggle/input/jutepest/train_images/data_5780.jpg
# /kaggle/input/jutepest/train_images/data_1478.jpg
# /kaggle/input/jutepest/train_images/data_381.jpg
# /kaggle/input/jutepest/train_images/data_3356.jpg
# /kaggle/input/jutepest/train_images/data_3983.jpg
# /kaggle/input/jutepest/train_images/data_3066.jpg
# /kaggle/input/jutepest/train_images/data_5226.jpg
# /kaggle/input/jutepest/train_images/data_1988.jpg
# /kaggle/input/jutepest/train_images/data_3981.jpg
# /kaggle/input/jutepest/train_images/data_5875.jpg
# /kaggle/input/jutepest/train_images/data_1763.jpg
# /kaggle/input/jutepest/train_images/data_4927.jpg
# /kaggle/input/jutepest/train_images/data_6674.jpg
# /kaggle/input/jutepest/train_images/data_3349.jpg
# /kaggle/input/jutepest/train_images/data_3011.jpg
# /kaggle/input/jutepest/train_images/data_849.jpg
# /kaggle/input/jutepest/train_images/data_6884.jpg
# /kaggle/input/jutepest/train_images/data_2800.jpg
# /kaggle/input/jutepest/train_images/data_1364.jpg
# /kaggle/input/jutepest/train_images/data_3013.jpg
# /kaggle/input/jutepest/train_images/data_5815.jpg
# /kaggle/input/jutepest/train_images/data_3940.jpg
# /kaggle/input/jutepest/train_images/data_1897.jpg
# /kaggle/input/jutepest/train_images/data_2291.jpg
# /kaggle/input/jutepest/train_images/data_2472.jpg
# /kaggle/input/jutepest/train_images/data_3556.jpg
# /kaggle/input/jutepest/train_images/data_6008.jpg
# /kaggle/input/jutepest/train_images/data_1530.jpg
# /kaggle/input/jutepest/train_images/data_3084.jpg
# /kaggle/input/jutepest/train_images/data_5400.jpg
# /kaggle/input/jutepest/train_images/data_4283.jpg
# /kaggle/input/jutepest/train_images/data_2498.jpg
# /kaggle/input/jutepest/train_images/data_5227.jpg
# /kaggle/input/jutepest/train_images/data_5477.jpg
# /kaggle/input/jutepest/train_images/data_4858.jpg
# /kaggle/input/jutepest/train_images/data_6488.jpg
# /kaggle/input/jutepest/train_images/data_4714.jpg
# /kaggle/input/jutepest/train_images/data_5398.jpg
# /kaggle/input/jutepest/train_images/data_2749.jpg
# /kaggle/input/jutepest/train_images/data_658.jpg
# /kaggle/input/jutepest/train_images/data_2178.jpg
# /kaggle/input/jutepest/train_images/data_6334.jpg
# /kaggle/input/jutepest/train_images/data_64.jpg
# /kaggle/input/jutepest/train_images/data_3501.jpg
# /kaggle/input/jutepest/train_images/data_1184.jpg
# /kaggle/input/jutepest/train_images/data_4574.jpg
# /kaggle/input/jutepest/train_images/data_5896.jpg
# /kaggle/input/jutepest/train_images/data_5715.jpg
# /kaggle/input/jutepest/train_images/data_604.jpg
# /kaggle/input/jutepest/train_images/data_637.jpg
# /kaggle/input/jutepest/train_images/data_5250.jpg
# /kaggle/input/jutepest/train_images/data_884.jpg
# /kaggle/input/jutepest/train_images/data_4531.jpg
# /kaggle/input/jutepest/train_images/data_2302.jpg
# /kaggle/input/jutepest/train_images/data_4752.jpg
# /kaggle/input/jutepest/train_images/data_3312.jpg
# /kaggle/input/jutepest/train_images/data_1103.jpg
# /kaggle/input/jutepest/train_images/data_5298.jpg
# /kaggle/input/jutepest/train_images/data_7231.jpg
# /kaggle/input/jutepest/train_images/data_2264.jpg
# /kaggle/input/jutepest/train_images/data_3719.jpg
# /kaggle/input/jutepest/train_images/data_4321.jpg
# /kaggle/input/jutepest/train_images/data_951.jpg
# /kaggle/input/jutepest/train_images/data_3377.jpg
# /kaggle/input/jutepest/train_images/data_2168.jpg
# /kaggle/input/jutepest/train_images/data_3997.jpg
# /kaggle/input/jutepest/train_images/data_3298.jpg
# /kaggle/input/jutepest/train_images/data_1123.jpg
# /kaggle/input/jutepest/train_images/data_2847.jpg
# /kaggle/input/jutepest/train_images/data_531.jpg
# /kaggle/input/jutepest/train_images/data_2662.jpg
# /kaggle/input/jutepest/train_images/data_5240.jpg
# /kaggle/input/jutepest/train_images/data_170.jpg
# /kaggle/input/jutepest/train_images/data_3068.jpg
# /kaggle/input/jutepest/train_images/data_5461.jpg
# /kaggle/input/jutepest/train_images/data_4267.jpg
# /kaggle/input/jutepest/train_images/data_5812.jpg
# /kaggle/input/jutepest/train_images/data_4375.jpg
# /kaggle/input/jutepest/train_images/data_4605.jpg
# /kaggle/input/jutepest/train_images/data_4043.jpg
# /kaggle/input/jutepest/train_images/data_6317.jpg
# /kaggle/input/jutepest/train_images/data_5581.jpg
# /kaggle/input/jutepest/train_images/data_2807.jpg
# /kaggle/input/jutepest/train_images/data_3207.jpg
# /kaggle/input/jutepest/train_images/data_6994.jpg
# /kaggle/input/jutepest/train_images/data_6343.jpg
# /kaggle/input/jutepest/train_images/data_4929.jpg
# /kaggle/input/jutepest/train_images/data_5397.jpg
# /kaggle/input/jutepest/train_images/data_4430.jpg
# /kaggle/input/jutepest/train_images/data_5702.jpg
# /kaggle/input/jutepest/train_images/data_3581.jpg
# /kaggle/input/jutepest/train_images/data_175.jpg
# /kaggle/input/jutepest/train_images/data_2319.jpg
# /kaggle/input/jutepest/train_images/data_357.jpg
# /kaggle/input/jutepest/train_images/data_1155.jpg
# /kaggle/input/jutepest/train_images/data_7024.jpg
# /kaggle/input/jutepest/train_images/data_6135.jpg
# /kaggle/input/jutepest/train_images/data_549.jpg
# /kaggle/input/jutepest/train_images/data_3081.jpg
# /kaggle/input/jutepest/train_images/data_5305.jpg
# /kaggle/input/jutepest/train_images/data_5145.jpg
# /kaggle/input/jutepest/train_images/data_4538.jpg
# /kaggle/input/jutepest/train_images/data_6637.jpg
# /kaggle/input/jutepest/train_images/data_3126.jpg
# /kaggle/input/jutepest/train_images/data_1941.jpg
# /kaggle/input/jutepest/train_images/data_2482.jpg
# /kaggle/input/jutepest/train_images/data_2981.jpg
# /kaggle/input/jutepest/train_images/data_6218.jpg
# /kaggle/input/jutepest/train_images/data_394.jpg
# /kaggle/input/jutepest/train_images/data_3721.jpg
# /kaggle/input/jutepest/train_images/data_258.jpg
# /kaggle/input/jutepest/train_images/data_3760.jpg
# /kaggle/input/jutepest/train_images/data_6327.jpg
# /kaggle/input/jutepest/train_images/data_1513.jpg
# /kaggle/input/jutepest/train_images/data_307.jpg
# /kaggle/input/jutepest/train_images/data_5795.jpg
# /kaggle/input/jutepest/train_images/data_3256.jpg
# /kaggle/input/jutepest/train_images/data_1505.jpg
# /kaggle/input/jutepest/train_images/data_6219.jpg
# /kaggle/input/jutepest/train_images/data_6857.jpg
# /kaggle/input/jutepest/train_images/data_3717.jpg
# /kaggle/input/jutepest/train_images/data_1947.jpg
# /kaggle/input/jutepest/train_images/data_2430.jpg
# /kaggle/input/jutepest/train_images/data_5224.jpg
# /kaggle/input/jutepest/train_images/data_2192.jpg
# /kaggle/input/jutepest/train_images/data_3043.jpg
# /kaggle/input/jutepest/train_images/data_3089.jpg
# /kaggle/input/jutepest/train_images/data_5384.jpg
# /kaggle/input/jutepest/train_images/data_1193.jpg
# /kaggle/input/jutepest/train_images/data_3201.jpg
# /kaggle/input/jutepest/train_images/data_1482.jpg
# /kaggle/input/jutepest/train_images/data_3259.jpg
# /kaggle/input/jutepest/train_images/data_1632.jpg
# /kaggle/input/jutepest/train_images/data_5593.jpg
# /kaggle/input/jutepest/train_images/data_4340.jpg
# /kaggle/input/jutepest/train_images/data_4091.jpg
# /kaggle/input/jutepest/train_images/data_131.jpg
# /kaggle/input/jutepest/train_images/data_2051.jpg
# /kaggle/input/jutepest/train_images/data_6521.jpg
# /kaggle/input/jutepest/train_images/data_1408.jpg
# /kaggle/input/jutepest/train_images/data_2314.jpg
# /kaggle/input/jutepest/train_images/data_2395.jpg
# /kaggle/input/jutepest/train_images/data_2535.jpg
# /kaggle/input/jutepest/train_images/data_3846.jpg
# /kaggle/input/jutepest/train_images/data_5344.jpg
# /kaggle/input/jutepest/train_images/data_5718.jpg
# /kaggle/input/jutepest/train_images/data_2689.jpg
# /kaggle/input/jutepest/train_images/data_2976.jpg
# /kaggle/input/jutepest/train_images/data_1356.jpg
# /kaggle/input/jutepest/train_images/data_4586.jpg
# /kaggle/input/jutepest/train_images/data_1762.jpg
# /kaggle/input/jutepest/train_images/data_6253.jpg
# /kaggle/input/jutepest/train_images/data_7114.jpg
# /kaggle/input/jutepest/train_images/data_3978.jpg
# /kaggle/input/jutepest/train_images/data_2174.jpg
# /kaggle/input/jutepest/train_images/data_608.jpg
# /kaggle/input/jutepest/train_images/data_1023.jpg
# /kaggle/input/jutepest/train_images/data_1181.jpg
# /kaggle/input/jutepest/train_images/data_6550.jpg
# /kaggle/input/jutepest/train_images/data_2560.jpg
# /kaggle/input/jutepest/train_images/data_7153.jpg
# /kaggle/input/jutepest/train_images/data_5138.jpg
# /kaggle/input/jutepest/train_images/data_2261.jpg
# /kaggle/input/jutepest/train_images/data_6035.jpg
# /kaggle/input/jutepest/train_images/data_7049.jpg
# /kaggle/input/jutepest/train_images/data_2491.jpg
# /kaggle/input/jutepest/train_images/data_5802.jpg
# /kaggle/input/jutepest/train_images/data_3338.jpg
# /kaggle/input/jutepest/train_images/data_2669.jpg
# /kaggle/input/jutepest/train_images/data_3505.jpg
# /kaggle/input/jutepest/train_images/data_4767.jpg
# /kaggle/input/jutepest/train_images/data_598.jpg
# /kaggle/input/jutepest/train_images/data_3463.jpg
# /kaggle/input/jutepest/train_images/data_6353.jpg
# /kaggle/input/jutepest/train_images/data_5136.jpg
# /kaggle/input/jutepest/train_images/data_4844.jpg
# /kaggle/input/jutepest/train_images/data_1427.jpg
# /kaggle/input/jutepest/train_images/data_3585.jpg
# /kaggle/input/jutepest/train_images/data_1811.jpg
# /kaggle/input/jutepest/train_images/data_3928.jpg
# /kaggle/input/jutepest/train_images/data_3750.jpg
# /kaggle/input/jutepest/train_images/data_2582.jpg
# /kaggle/input/jutepest/train_images/data_215.jpg
# /kaggle/input/jutepest/train_images/data_5666.jpg
# /kaggle/input/jutepest/train_images/data_1180.jpg
# /kaggle/input/jutepest/train_images/data_6397.jpg
# /kaggle/input/jutepest/train_images/data_6900.jpg
# /kaggle/input/jutepest/train_images/data_6660.jpg
# /kaggle/input/jutepest/train_images/data_4467.jpg
# /kaggle/input/jutepest/train_images/data_6348.jpg
# /kaggle/input/jutepest/train_images/data_4129.jpg
# /kaggle/input/jutepest/train_images/data_6120.jpg
# /kaggle/input/jutepest/train_images/data_387.jpg
# /kaggle/input/jutepest/train_images/data_7043.jpg
# /kaggle/input/jutepest/train_images/data_3171.jpg
# /kaggle/input/jutepest/train_images/data_7201.jpg
# /kaggle/input/jutepest/train_images/data_5440.jpg
# /kaggle/input/jutepest/train_images/data_6308.jpg
# /kaggle/input/jutepest/train_images/data_6396.jpg
# /kaggle/input/jutepest/train_images/data_1409.jpg
# /kaggle/input/jutepest/train_images/data_5290.jpg
# /kaggle/input/jutepest/train_images/data_2985.jpg
# /kaggle/input/jutepest/train_images/data_2647.jpg
# /kaggle/input/jutepest/train_images/data_165.jpg
# /kaggle/input/jutepest/train_images/data_6930.jpg
# /kaggle/input/jutepest/train_images/data_5139.jpg
# /kaggle/input/jutepest/train_images/data_2978.jpg
# /kaggle/input/jutepest/train_images/data_2695.jpg
# /kaggle/input/jutepest/train_images/data_1662.jpg
# /kaggle/input/jutepest/train_images/data_3954.jpg
# /kaggle/input/jutepest/train_images/data_2545.jpg
# /kaggle/input/jutepest/train_images/data_5923.jpg
# /kaggle/input/jutepest/train_images/data_1175.jpg
# /kaggle/input/jutepest/train_images/data_5684.jpg
# /kaggle/input/jutepest/train_images/data_3057.jpg
# /kaggle/input/jutepest/train_images/data_5762.jpg
# /kaggle/input/jutepest/train_images/data_6168.jpg
# /kaggle/input/jutepest/train_images/data_4499.jpg
# /kaggle/input/jutepest/train_images/data_2656.jpg
# /kaggle/input/jutepest/train_images/data_3395.jpg
# /kaggle/input/jutepest/train_images/data_6617.jpg
# /kaggle/input/jutepest/train_images/data_1476.jpg
# /kaggle/input/jutepest/train_images/data_562.jpg
# /kaggle/input/jutepest/train_images/data_5082.jpg
# /kaggle/input/jutepest/train_images/data_5123.jpg
# /kaggle/input/jutepest/train_images/data_4009.jpg
# /kaggle/input/jutepest/train_images/data_2958.jpg
# /kaggle/input/jutepest/train_images/data_5634.jpg
# /kaggle/input/jutepest/train_images/data_3743.jpg
# /kaggle/input/jutepest/train_images/data_159.jpg
# /kaggle/input/jutepest/train_images/data_5602.jpg
# /kaggle/input/jutepest/train_images/data_6301.jpg
# /kaggle/input/jutepest/train_images/data_5900.jpg
# /kaggle/input/jutepest/train_images/data_6191.jpg
# /kaggle/input/jutepest/train_images/data_2382.jpg
# /kaggle/input/jutepest/train_images/data_5939.jpg
# /kaggle/input/jutepest/train_images/data_2224.jpg
# /kaggle/input/jutepest/train_images/data_6565.jpg
# /kaggle/input/jutepest/train_images/data_7115.jpg
# /kaggle/input/jutepest/train_images/data_4322.jpg
# /kaggle/input/jutepest/train_images/data_3716.jpg
# /kaggle/input/jutepest/train_images/data_125.jpg
# /kaggle/input/jutepest/train_images/data_6014.jpg
# /kaggle/input/jutepest/train_images/data_3061.jpg
# /kaggle/input/jutepest/train_images/data_7068.jpg
# /kaggle/input/jutepest/train_images/data_5495.jpg
# /kaggle/input/jutepest/train_images/data_4987.jpg
# /kaggle/input/jutepest/train_images/data_5120.jpg
# /kaggle/input/jutepest/train_images/data_1825.jpg
# /kaggle/input/jutepest/train_images/data_4269.jpg
# /kaggle/input/jutepest/train_images/data_47.jpg
# /kaggle/input/jutepest/train_images/data_4880.jpg
# /kaggle/input/jutepest/train_images/data_366.jpg
# /kaggle/input/jutepest/train_images/data_4022.jpg
# /kaggle/input/jutepest/train_images/data_6058.jpg
# /kaggle/input/jutepest/train_images/data_6737.jpg
# /kaggle/input/jutepest/train_images/data_5427.jpg
# /kaggle/input/jutepest/train_images/data_3539.jpg
# /kaggle/input/jutepest/train_images/data_3260.jpg
# /kaggle/input/jutepest/train_images/data_4417.jpg
# /kaggle/input/jutepest/train_images/data_1653.jpg
# /kaggle/input/jutepest/train_images/data_3189.jpg
# /kaggle/input/jutepest/train_images/data_4202.jpg
# /kaggle/input/jutepest/train_images/data_1274.jpg
# /kaggle/input/jutepest/train_images/data_6424.jpg
# /kaggle/input/jutepest/train_images/data_5922.jpg
# /kaggle/input/jutepest/train_images/data_2452.jpg
# /kaggle/input/jutepest/train_images/data_6862.jpg
# /kaggle/input/jutepest/train_images/data_270.jpeg
# /kaggle/input/jutepest/train_images/data_5291.jpg
# /kaggle/input/jutepest/train_images/data_2342.jpg
# /kaggle/input/jutepest/train_images/data_3272.jpg
# /kaggle/input/jutepest/train_images/data_5804.jpg
# /kaggle/input/jutepest/train_images/data_4991.jpg
# /kaggle/input/jutepest/train_images/data_99.jpg
# /kaggle/input/jutepest/train_images/data_1458.jpg
# /kaggle/input/jutepest/train_images/data_6055.jpg
# /kaggle/input/jutepest/train_images/data_3220.jpg
# /kaggle/input/jutepest/train_images/data_40.jpg
# /kaggle/input/jutepest/train_images/data_1144.jpg
# /kaggle/input/jutepest/train_images/data_5826.jpg
# /kaggle/input/jutepest/train_images/data_430.jpg
# /kaggle/input/jutepest/train_images/data_5992.jpg
# /kaggle/input/jutepest/train_images/data_7170.jpg
# /kaggle/input/jutepest/train_images/data_7204.jpg
# /kaggle/input/jutepest/train_images/data_432.jpg
# /kaggle/input/jutepest/train_images/data_1809.jpg
# /kaggle/input/jutepest/train_images/data_3628.jpg
# /kaggle/input/jutepest/train_images/data_2748.jpg
# /kaggle/input/jutepest/train_images/data_1368.jpg
# /kaggle/input/jutepest/train_images/data_3877.jpg
# /kaggle/input/jutepest/train_images/data_6990.jpg
# /kaggle/input/jutepest/train_images/data_2828.jpg
# /kaggle/input/jutepest/train_images/data_4103.jpg
# /kaggle/input/jutepest/train_images/data_5457.jpg
# /kaggle/input/jutepest/train_images/data_2195.jpg
# /kaggle/input/jutepest/train_images/data_822.jpg
# /kaggle/input/jutepest/train_images/data_4171.jpg
# /kaggle/input/jutepest/train_images/data_6287.jpg
# /kaggle/input/jutepest/train_images/data_6999.jpg
# /kaggle/input/jutepest/train_images/data_2085.jpg
# /kaggle/input/jutepest/train_images/data_4313.jpg
# /kaggle/input/jutepest/train_images/data_4901.jpg
# /kaggle/input/jutepest/train_images/data_2934.jpg
# /kaggle/input/jutepest/train_images/data_6449.jpg
# /kaggle/input/jutepest/train_images/data_7041.jpg
# /kaggle/input/jutepest/train_images/data_711.jpg
# /kaggle/input/jutepest/train_images/data_758.jpg
# /kaggle/input/jutepest/train_images/data_694.jpg
# /kaggle/input/jutepest/train_images/data_2880.jpg
# /kaggle/input/jutepest/train_images/data_5745.jpg
# /kaggle/input/jutepest/train_images/data_1309.jpg
# /kaggle/input/jutepest/train_images/data_6870.jpg
# /kaggle/input/jutepest/train_images/data_1828.jpg
# /kaggle/input/jutepest/train_images/data_116.jpg
# /kaggle/input/jutepest/train_images/data_889.jpg
# /kaggle/input/jutepest/train_images/data_1424.jpg
# /kaggle/input/jutepest/train_images/data_5421.jpg
# /kaggle/input/jutepest/train_images/data_5152.jpg
# /kaggle/input/jutepest/train_images/data_5172.jpg
# /kaggle/input/jutepest/train_images/data_3874.jpg
# /kaggle/input/jutepest/train_images/data_3105.jpg
# /kaggle/input/jutepest/train_images/data_3498.jpg
# /kaggle/input/jutepest/train_images/data_2825.jpg
# /kaggle/input/jutepest/train_images/data_4372.jpg
# /kaggle/input/jutepest/train_images/data_4741.jpg
# /kaggle/input/jutepest/train_images/data_5730.jpg
# /kaggle/input/jutepest/train_images/data_5759.jpg
# /kaggle/input/jutepest/train_images/data_702.jpg
# /kaggle/input/jutepest/train_images/data_3258.jpg
# /kaggle/input/jutepest/train_images/data_4209.jpg
# /kaggle/input/jutepest/train_images/data_1620.jpg
# /kaggle/input/jutepest/train_images/data_2139.jpg
# /kaggle/input/jutepest/train_images/data_6991.jpg
# /kaggle/input/jutepest/train_images/data_1126.jpg
# /kaggle/input/jutepest/train_images/data_1469.jpg
# /kaggle/input/jutepest/train_images/data_5958.jpg
# /kaggle/input/jutepest/train_images/data_405.jpg
# /kaggle/input/jutepest/train_images/data_7205.jpg
# /kaggle/input/jutepest/train_images/data_1321.jpg
# /kaggle/input/jutepest/train_images/data_3713.jpg
# /kaggle/input/jutepest/train_images/data_6335.jpg
# /kaggle/input/jutepest/train_images/data_6911.jpg
# /kaggle/input/jutepest/train_images/data_6664.jpg
# /kaggle/input/jutepest/train_images/data_6747.jpg
# /kaggle/input/jutepest/train_images/data_6560.jpg
# /kaggle/input/jutepest/train_images/data_6270.jpg
# /kaggle/input/jutepest/train_images/data_2447.jpg
# /kaggle/input/jutepest/train_images/data_3114.jpg
# /kaggle/input/jutepest/train_images/data_601.jpg
# /kaggle/input/jutepest/train_images/data_3038.jpg
# /kaggle/input/jutepest/train_images/data_848.jpg
# /kaggle/input/jutepest/train_images/data_2704.jpg
# /kaggle/input/jutepest/train_images/data_4887.jpg
# /kaggle/input/jutepest/train_images/data_1367.jpg
# /kaggle/input/jutepest/train_images/data_2122.jpg
# /kaggle/input/jutepest/train_images/data_4513.jpg
# /kaggle/input/jutepest/train_images/data_1795.jpg
# /kaggle/input/jutepest/train_images/data_2146.jpg
# /kaggle/input/jutepest/train_images/data_1138.jpg
# /kaggle/input/jutepest/train_images/data_5278.jpg
# /kaggle/input/jutepest/train_images/data_3122.jpg
# /kaggle/input/jutepest/train_images/data_293.jpg
# /kaggle/input/jutepest/train_images/data_2733.jpg
# /kaggle/input/jutepest/train_images/data_2565.jpg
# /kaggle/input/jutepest/train_images/data_2309.jpg
# /kaggle/input/jutepest/train_images/data_1014.jpg
# /kaggle/input/jutepest/train_images/data_2650.jpg
# /kaggle/input/jutepest/train_images/data_1296.jpg
# /kaggle/input/jutepest/train_images/data_6321.jpg
# /kaggle/input/jutepest/train_images/data_2352.jpg
# /kaggle/input/jutepest/train_images/data_3888.jpg
# /kaggle/input/jutepest/train_images/data_2955.jpg
# /kaggle/input/jutepest/train_images/data_3268.jpg
# /kaggle/input/jutepest/train_images/data_1538.jpg
# /kaggle/input/jutepest/train_images/data_885.jpg
# /kaggle/input/jutepest/train_images/data_369.jpg
# /kaggle/input/jutepest/train_images/data_3984.jpg
# /kaggle/input/jutepest/train_images/data_6959.jpg
# /kaggle/input/jutepest/train_images/data_4246.jpg
# /kaggle/input/jutepest/train_images/data_4932.jpg
# /kaggle/input/jutepest/train_images/data_2941.jpg
# /kaggle/input/jutepest/train_images/data_3700.jpg
# /kaggle/input/jutepest/train_images/data_3758.jpg
# /kaggle/input/jutepest/train_images/data_2624.jpg
# /kaggle/input/jutepest/train_images/data_3139.jpg
# /kaggle/input/jutepest/train_images/data_5233.jpg
# /kaggle/input/jutepest/train_images/data_3740.jpg
# /kaggle/input/jutepest/train_images/data_3776.jpg
# /kaggle/input/jutepest/train_images/data_6563.jpg
# /kaggle/input/jutepest/train_images/data_2233.jpg
# /kaggle/input/jutepest/train_images/data_4330.jpg
# /kaggle/input/jutepest/train_images/data_4980.jpg
# /kaggle/input/jutepest/train_images/data_3213.jpg
# /kaggle/input/jutepest/train_images/data_7150.jpg
# /kaggle/input/jutepest/train_images/data_2405.jpg
# /kaggle/input/jutepest/train_images/data_6382.jpg
# /kaggle/input/jutepest/train_images/data_2929.jpg
# /kaggle/input/jutepest/train_images/data_5976.jpg
# /kaggle/input/jutepest/train_images/data_971.jpg
# /kaggle/input/jutepest/train_images/data_449.jpg
# /kaggle/input/jutepest/train_images/data_762.jpg
# /kaggle/input/jutepest/train_images/data_4097.jpg
# /kaggle/input/jutepest/train_images/data_6525.jpg
# /kaggle/input/jutepest/train_images/data_4402.jpg
# /kaggle/input/jutepest/train_images/data_610.jpg
# /kaggle/input/jutepest/train_images/data_4909.jpg
# /kaggle/input/jutepest/train_images/data_5603.jpg
# /kaggle/input/jutepest/train_images/data_5928.jpg
# /kaggle/input/jutepest/train_images/data_5043.jpg
# /kaggle/input/jutepest/train_images/data_4644.jpg
# /kaggle/input/jutepest/train_images/data_4074.jpg
# /kaggle/input/jutepest/train_images/data_6679.jpg
# /kaggle/input/jutepest/train_images/data_3093.jpg
# /kaggle/input/jutepest/train_images/data_3860.jpg
# /kaggle/input/jutepest/train_images/data_292.jpg
# /kaggle/input/jutepest/train_images/data_296.jpg
# /kaggle/input/jutepest/train_images/data_5810.jpg
# /kaggle/input/jutepest/train_images/data_2091.jpg
# /kaggle/input/jutepest/train_images/data_1602.jpg
# /kaggle/input/jutepest/train_images/data_6539.jpg
# /kaggle/input/jutepest/train_images/data_7081.jpg
# /kaggle/input/jutepest/train_images/data_6243.jpg
# /kaggle/input/jutepest/train_images/data_714.jpg
# /kaggle/input/jutepest/train_images/data_234.jpg
# /kaggle/input/jutepest/train_images/data_801.jpg
# /kaggle/input/jutepest/train_images/data_4943.jpg
# /kaggle/input/jutepest/train_images/data_2188.jpg
# /kaggle/input/jutepest/train_images/data_6216.jpg
# /kaggle/input/jutepest/train_images/data_1776.jpg
# /kaggle/input/jutepest/train_images/data_5378.jpg
# /kaggle/input/jutepest/train_images/data_2012.jpg
# /kaggle/input/jutepest/train_images/data_4812.jpg
# /kaggle/input/jutepest/train_images/data_6177.jpg
# /kaggle/input/jutepest/train_images/data_770.jpg
# /kaggle/input/jutepest/train_images/data_6312.jpg
# /kaggle/input/jutepest/train_images/data_28.jpg
# /kaggle/input/jutepest/train_images/data_5499.jpg
# /kaggle/input/jutepest/train_images/data_3934.jpg
# /kaggle/input/jutepest/train_images/data_6749.jpg
# /kaggle/input/jutepest/train_images/data_1171.jpg
# /kaggle/input/jutepest/train_images/data_1965.jpg
# /kaggle/input/jutepest/train_images/data_7189.jpg
# /kaggle/input/jutepest/train_images/data_4872.jpg
# /kaggle/input/jutepest/train_images/data_2508.jpg
# /kaggle/input/jutepest/train_images/data_4339.jpg
# /kaggle/input/jutepest/train_images/data_2641.jpg
# /kaggle/input/jutepest/train_images/data_6596.jpg
# /kaggle/input/jutepest/train_images/data_3307.jpg
# /kaggle/input/jutepest/train_images/data_6463.jpg
# /kaggle/input/jutepest/train_images/data_2323.jpg
# /kaggle/input/jutepest/train_images/data_7030.jpg
# /kaggle/input/jutepest/train_images/data_6820.jpg
# /kaggle/input/jutepest/train_images/data_4107.jpg
# /kaggle/input/jutepest/train_images/data_4124.jpg
# /kaggle/input/jutepest/train_images/data_3508.jpg
# /kaggle/input/jutepest/train_images/data_6652.jpg
# /kaggle/input/jutepest/train_images/data_2207.jpg
# /kaggle/input/jutepest/train_images/data_936.jpg
# /kaggle/input/jutepest/train_images/data_4210.jpg
# /kaggle/input/jutepest/train_images/data_992.jpg
# /kaggle/input/jutepest/train_images/data_1161.jpg
# /kaggle/input/jutepest/train_images/data_2397.jpg
# /kaggle/input/jutepest/train_images/data_2892.jpg
# /kaggle/input/jutepest/train_images/data_4563.jpg
# /kaggle/input/jutepest/train_images/data_4614.jpg
# /kaggle/input/jutepest/train_images/data_2486.jpg
# /kaggle/input/jutepest/train_images/data_2550.jpg
# /kaggle/input/jutepest/train_images/data_3789.jpg
# /kaggle/input/jutepest/train_images/data_5143.jpg
# /kaggle/input/jutepest/train_images/data_1272.jpg
# /kaggle/input/jutepest/train_images/data_7001.jpg
# /kaggle/input/jutepest/train_images/data_837.jpg
# /kaggle/input/jutepest/train_images/data_6825.jpg
# /kaggle/input/jutepest/train_images/data_6778.jpg
# /kaggle/input/jutepest/train_images/data_735.jpg
# /kaggle/input/jutepest/train_images/data_1600.jpg
# /kaggle/input/jutepest/train_images/data_1317.jpg
# /kaggle/input/jutepest/train_images/data_1249.jpg
# /kaggle/input/jutepest/train_images/data_237.jpg
# /kaggle/input/jutepest/train_images/data_1003.jpg
# /kaggle/input/jutepest/train_images/data_2573.jpg
# /kaggle/input/jutepest/train_images/data_3509.jpg
# /kaggle/input/jutepest/train_images/data_2770.jpg
# /kaggle/input/jutepest/train_images/data_4181.jpg
# /kaggle/input/jutepest/train_images/data_4651.jpg
# /kaggle/input/jutepest/train_images/data_3500.jpg
# /kaggle/input/jutepest/train_images/data_5020.jpg
# /kaggle/input/jutepest/train_images/data_6006.jpg
# /kaggle/input/jutepest/train_images/data_5060.jpg
# /kaggle/input/jutepest/train_images/data_1637.jpg
# /kaggle/input/jutepest/train_images/data_1362.jpg
# /kaggle/input/jutepest/train_images/data_5402.jpg
# /kaggle/input/jutepest/train_images/data_6827.jpg
# /kaggle/input/jutepest/train_images/data_3132.jpg
# /kaggle/input/jutepest/train_images/data_3578.jpg
# /kaggle/input/jutepest/train_images/data_3868.jpg
# /kaggle/input/jutepest/train_images/data_6663.jpg
# /kaggle/input/jutepest/train_images/data_2802.jpg
# /kaggle/input/jutepest/train_images/data_732.jpg
# /kaggle/input/jutepest/train_images/data_5620.jpg
# /kaggle/input/jutepest/train_images/data_2542.jpg
# /kaggle/input/jutepest/train_images/data_3730.jpg
# /kaggle/input/jutepest/train_images/data_4699.jpg
# /kaggle/input/jutepest/train_images/data_7005.jpg
# /kaggle/input/jutepest/train_images/data_7045.jpg
# /kaggle/input/jutepest/train_images/data_6130.jpg
# /kaggle/input/jutepest/train_images/data_6586.jpg
# /kaggle/input/jutepest/train_images/data_4039.jpg
# /kaggle/input/jutepest/train_images/data_4969.jpg
# /kaggle/input/jutepest/train_images/data_3458.jpg
# /kaggle/input/jutepest/train_images/data_2901.jpg
# /kaggle/input/jutepest/train_images/data_6620.jpg
# /kaggle/input/jutepest/train_images/data_3245.jpg
# /kaggle/input/jutepest/train_images/data_6194.jpg
# /kaggle/input/jutepest/train_images/data_5194.jpg
# /kaggle/input/jutepest/train_images/data_3658.jpg
# /kaggle/input/jutepest/train_images/data_5514.jpg
# /kaggle/input/jutepest/train_images/data_5680.jpg
# /kaggle/input/jutepest/train_images/data_491.jpg
# /kaggle/input/jutepest/train_images/data_818.jpg
# /kaggle/input/jutepest/train_images/data_5845.jpg
# /kaggle/input/jutepest/train_images/data_6976.jpg
# /kaggle/input/jutepest/train_images/data_888.jpg
# /kaggle/input/jutepest/train_images/data_7149.jpg
# /kaggle/input/jutepest/train_images/data_5778.jpg
# /kaggle/input/jutepest/train_images/data_836.jpg
# /kaggle/input/jutepest/train_images/data_1021.jpg
# /kaggle/input/jutepest/train_images/data_2846.jpg
# /kaggle/input/jutepest/train_images/data_1319.jpg
# /kaggle/input/jutepest/train_images/data_5763.jpg
# /kaggle/input/jutepest/train_images/data_5185.jpg
# /kaggle/input/jutepest/train_images/data_5526.jpg
# /kaggle/input/jutepest/train_images/data_1280.jpg
# /kaggle/input/jutepest/train_images/data_5197.jpg
# /kaggle/input/jutepest/train_images/data_7183.jpg
# /kaggle/input/jutepest/train_images/data_917.jpg
# /kaggle/input/jutepest/train_images/data_7211.jpg
# /kaggle/input/jutepest/train_images/data_932.jpg
# /kaggle/input/jutepest/train_images/data_3955.jpg
# /kaggle/input/jutepest/train_images/data_42.jpg
# /kaggle/input/jutepest/train_images/data_879.jpg
# /kaggle/input/jutepest/train_images/data_6544.jpg
# /kaggle/input/jutepest/train_images/data_4856.jpg
# /kaggle/input/jutepest/train_images/data_5234.jpg
# /kaggle/input/jutepest/train_images/data_968.jpg
# /kaggle/input/jutepest/train_images/data_3791.jpg
# /kaggle/input/jutepest/train_images/data_1204.jpg
# /kaggle/input/jutepest/train_images/data_3451.jpg
# /kaggle/input/jutepest/train_images/data_5551.jpg
# /kaggle/input/jutepest/train_images/data_904.jpg
# /kaggle/input/jutepest/train_images/data_3748.jpg
# /kaggle/input/jutepest/train_images/data_5055.jpg
# /kaggle/input/jutepest/train_images/data_6822.jpg
# /kaggle/input/jutepest/train_images/data_1108.jpg
# /kaggle/input/jutepest/train_images/data_5511.jpg
# /kaggle/input/jutepest/train_images/data_6933.jpg
# /kaggle/input/jutepest/train_images/data_3270.jpg
# /kaggle/input/jutepest/train_images/data_3480.jpg
# /kaggle/input/jutepest/train_images/data_571.jpg
# /kaggle/input/jutepest/train_images/data_6325.jpg
# /kaggle/input/jutepest/train_images/data_1265.jpg
# /kaggle/input/jutepest/train_images/data_4392.jpg
# /kaggle/input/jutepest/train_images/data_3413.jpg
# /kaggle/input/jutepest/train_images/data_2989.jpg
# /kaggle/input/jutepest/train_images/data_3168.jpg
# /kaggle/input/jutepest/train_images/data_6465.jpg
# /kaggle/input/jutepest/train_images/data_4059.jpg
# /kaggle/input/jutepest/train_images/data_2741.jpg
# /kaggle/input/jutepest/train_images/data_5850.jpg
# /kaggle/input/jutepest/train_images/data_5428.jpg
# /kaggle/input/jutepest/train_images/data_704.jpg
# /kaggle/input/jutepest/train_images/data_3022.jpg
# /kaggle/input/jutepest/train_images/data_5168.jpg
# /kaggle/input/jutepest/train_images/data_5656.jpg
# /kaggle/input/jutepest/train_images/data_5727.jpg
# /kaggle/input/jutepest/train_images/data_5891.jpg
# /kaggle/input/jutepest/train_images/data_4487.jpg
# /kaggle/input/jutepest/train_images/data_5153.jpg
# /kaggle/input/jutepest/train_images/data_3862.jpg
# /kaggle/input/jutepest/train_images/data_7184.jpg
# /kaggle/input/jutepest/train_images/data_321.jpg
# /kaggle/input/jutepest/train_images/data_6207.jpg
# /kaggle/input/jutepest/train_images/data_7139.jpg
# /kaggle/input/jutepest/train_images/data_3650.jpg
# /kaggle/input/jutepest/train_images/data_3606.jpg
# /kaggle/input/jutepest/train_images/data_4055.jpg
# /kaggle/input/jutepest/train_images/data_1232.jpg
# /kaggle/input/jutepest/train_images/data_2317.jpg
# /kaggle/input/jutepest/train_images/data_3227.jpg
# /kaggle/input/jutepest/train_images/data_6916.jpg
# /kaggle/input/jutepest/train_images/data_404.jpg
# /kaggle/input/jutepest/train_images/data_3374.jpg
# /kaggle/input/jutepest/train_images/data_5817.jpg
# /kaggle/input/jutepest/train_images/data_1928.jpg
# /kaggle/input/jutepest/train_images/data_1579.jpg
# /kaggle/input/jutepest/train_images/data_2848.jpg
# /kaggle/input/jutepest/train_images/data_7215.jpg
# /kaggle/input/jutepest/train_images/data_3415.jpg
# /kaggle/input/jutepest/train_images/data_5023.jpg
# /kaggle/input/jutepest/train_images/data_512.jpg
# /kaggle/input/jutepest/train_images/data_730.jpg
# /kaggle/input/jutepest/train_images/data_1095.jpg
# /kaggle/input/jutepest/train_images/data_5425.jpg
# /kaggle/input/jutepest/train_images/data_5362.jpg
# /kaggle/input/jutepest/train_images/data_6918.jpg
# /kaggle/input/jutepest/train_images/data_4239.jpg
# /kaggle/input/jutepest/train_images/data_2722.jpg
# /kaggle/input/jutepest/train_images/data_3829.jpg
# /kaggle/input/jutepest/train_images/data_2912.jpg
# /kaggle/input/jutepest/train_images/data_5324.jpg
# /kaggle/input/jutepest/train_images/data_3872.jpg
# /kaggle/input/jutepest/train_images/data_1959.jpg
# /kaggle/input/jutepest/train_images/data_6705.JPG
# /kaggle/input/jutepest/train_images/data_1363.jpg
# /kaggle/input/jutepest/train_images/data_2972.jpg
# /kaggle/input/jutepest/train_images/data_3566.jpg
# /kaggle/input/jutepest/train_images/data_2031.jpg
# /kaggle/input/jutepest/train_images/data_3300.jpg
# /kaggle/input/jutepest/train_images/data_2851.jpg
# /kaggle/input/jutepest/train_images/data_3797.jpg
# /kaggle/input/jutepest/train_images/data_3363.jpg
# /kaggle/input/jutepest/train_images/data_332.jpg
# /kaggle/input/jutepest/train_images/data_3445.jpg
# /kaggle/input/jutepest/train_images/data_3064.jpg
# /kaggle/input/jutepest/train_images/data_1751.jpg
# /kaggle/input/jutepest/train_images/data_146.jpg
# /kaggle/input/jutepest/train_images/data_4852.jpg
# /kaggle/input/jutepest/train_images/data_519.jpg
# /kaggle/input/jutepest/train_images/data_7212.jpg
# /kaggle/input/jutepest/train_images/data_6036.jpg
# /kaggle/input/jutepest/train_images/data_4261.jpg
# /kaggle/input/jutepest/train_images/data_4795.jpg
# /kaggle/input/jutepest/train_images/data_6358.jpg
# /kaggle/input/jutepest/train_images/data_1389.jpg
# /kaggle/input/jutepest/train_images/data_1176.jpg
# /kaggle/input/jutepest/train_images/data_2946.jpg
# /kaggle/input/jutepest/train_images/data_399.jpg
# /kaggle/input/jutepest/train_images/data_6802.jpg
# /kaggle/input/jutepest/train_images/data_5898.jpg
# /kaggle/input/jutepest/train_images/data_5323.jpg
# /kaggle/input/jutepest/train_images/data_6728.jpg
# /kaggle/input/jutepest/train_images/data_6125.jpg
# /kaggle/input/jutepest/train_images/data_5094.jpg
# /kaggle/input/jutepest/train_images/data_3966.jpg
# /kaggle/input/jutepest/train_images/data_4381.jpg
# /kaggle/input/jutepest/train_images/data_3167.jpg
# /kaggle/input/jutepest/train_images/data_6000.jpg
# /kaggle/input/jutepest/train_images/data_7056.jpg
# /kaggle/input/jutepest/train_images/data_1016.jpg
# /kaggle/input/jutepest/train_images/data_6591.jpg
# /kaggle/input/jutepest/train_images/data_6877.jpg
# /kaggle/input/jutepest/train_images/data_6897.jpg
# /kaggle/input/jutepest/train_images/data_1395.jpg
# /kaggle/input/jutepest/train_images/data_2698.jpg
# /kaggle/input/jutepest/train_images/data_294.jpg
# /kaggle/input/jutepest/train_images/data_2764.jpg
# /kaggle/input/jutepest/train_images/data_2629.jpg
# /kaggle/input/jutepest/train_images/data_4805.jpg
# /kaggle/input/jutepest/train_images/data_5271.jpg
# /kaggle/input/jutepest/train_images/data_3075.jpg
# /kaggle/input/jutepest/train_images/data_1076.jpg
# /kaggle/input/jutepest/train_images/data_5739.jpg
# /kaggle/input/jutepest/train_images/data_1260.jpg
# /kaggle/input/jutepest/train_images/data_145.jpg
# /kaggle/input/jutepest/train_images/data_990.jpg
# /kaggle/input/jutepest/train_images/data_4434.jpg
# /kaggle/input/jutepest/train_images/data_621.jpg
# /kaggle/input/jutepest/train_images/data_1860.jpg
# /kaggle/input/jutepest/train_images/data_5991.jpg
# /kaggle/input/jutepest/train_images/data_2499.jpg
# /kaggle/input/jutepest/train_images/data_4295.jpg
# /kaggle/input/jutepest/train_images/data_4797.jpg
# /kaggle/input/jutepest/train_images/data_5567.jpg
# /kaggle/input/jutepest/train_images/data_5930.jpg
# /kaggle/input/jutepest/train_images/data_1461.jpg
# /kaggle/input/jutepest/train_images/data_1583.jpg
# /kaggle/input/jutepest/train_images/data_4289.jpg
# /kaggle/input/jutepest/train_images/data_3587.jpg
# /kaggle/input/jutepest/train_images/data_4258.jpg
# /kaggle/input/jutepest/train_images/data_3186.jpg
# /kaggle/input/jutepest/train_images/data_3264.jpg
# /kaggle/input/jutepest/train_images/data_5460.jpg
# /kaggle/input/jutepest/train_images/data_3842.jpg
# /kaggle/input/jutepest/train_images/data_3452.jpg
# /kaggle/input/jutepest/train_images/data_883.jpg
# /kaggle/input/jutepest/train_images/data_4090.jpg
# /kaggle/input/jutepest/train_images/data_7151.jpg
# /kaggle/input/jutepest/train_images/data_1746.jpg
# /kaggle/input/jutepest/train_images/data_6082.jpg
# /kaggle/input/jutepest/train_images/data_4111.jpg
# /kaggle/input/jutepest/train_images/data_3809.jpg
# /kaggle/input/jutepest/train_images/data_1229.jpg
# /kaggle/input/jutepest/train_images/data_3778.jpg
# /kaggle/input/jutepest/train_images/data_6231.jpg
# /kaggle/input/jutepest/train_images/data_1507.jpg
# /kaggle/input/jutepest/train_images/data_242.jpg
# /kaggle/input/jutepest/train_images/data_6590.jpg
# /kaggle/input/jutepest/train_images/data_2813.jpg
# /kaggle/input/jutepest/train_images/data_7200.jpg
# /kaggle/input/jutepest/train_images/data_1623.jpg
# /kaggle/input/jutepest/train_images/data_6370.jpg
# /kaggle/input/jutepest/train_images/data_2548.jpg
# /kaggle/input/jutepest/train_images/data_6017.jpg
# /kaggle/input/jutepest/train_images/data_2492.jpg
# /kaggle/input/jutepest/train_images/data_4601.jpg
# /kaggle/input/jutepest/train_images/data_261.jpg
# /kaggle/input/jutepest/train_images/data_712.jpg
# /kaggle/input/jutepest/train_images/data_4353.jpg
# /kaggle/input/jutepest/train_images/data_2953.jpg
# /kaggle/input/jutepest/train_images/data_5489.jpg
# /kaggle/input/jutepest/train_images/data_2376.jpg
# /kaggle/input/jutepest/train_images/data_996.jpg
# /kaggle/input/jutepest/train_images/data_4931.jpg
# /kaggle/input/jutepest/train_images/data_2155.jpg
# /kaggle/input/jutepest/train_images/data_675.jpg
# /kaggle/input/jutepest/train_images/data_3334.jpg
# /kaggle/input/jutepest/train_images/data_7106.jpg
# /kaggle/input/jutepest/train_images/data_1651.jpg
# /kaggle/input/jutepest/train_images/data_6939.jpg
# /kaggle/input/jutepest/train_images/data_2904.jpg
# ...
# /kaggle/input/jutepest/test_images/data_4708.jpg
# /kaggle/input/jutepest/test_images/data_287.jpg
# /kaggle/input/jutepest/test_images/data_235.jpg
# /kaggle/input/jutepest/test_images/data_1668.jpg
# /kaggle/input/jutepest/test_images/data_660.jpg
# /kaggle/input/jutepest/test_images/data_3235.jpg
# /kaggle/input/jutepest/test_images/data_920.jpg
# /kaggle/input/jutepest/test_images/data_1080.jpg
# /kaggle/input/jutepest/test_images/data_6661.jpg
# /kaggle/input/jutepest/test_images/data_6686.jpg
# /kaggle/input/jutepest/test_images/data_1329.jpg
# /kaggle/input/jutepest/test_images/data_761.jpg
# /kaggle/input/jutepest/test_images/data_6078.jpg
# /kaggle/input/jutepest/test_images/data_2894.jpg
# /kaggle/input/jutepest/test_images/data_3773.jpg
# /kaggle/input/jutepest/test_images/data_4917.jpg
# /kaggle/input/jutepest/test_images/data_3767.jpg
# /kaggle/input/jutepest/test_images/data_3113.jpg
# /kaggle/input/jutepest/test_images/data_6411.jpg
# /kaggle/input/jutepest/test_images/data_1346.jpg
# /kaggle/input/jutepest/test_images/data_2027.jpg
# /kaggle/input/jutepest/test_images/data_2995.jpg
# /kaggle/input/jutepest/test_images/data_1550.jpg
# /kaggle/input/jutepest/test_images/data_1318.jpg
# /kaggle/input/jutepest/test_images/data_227.jpg
# /kaggle/input/jutepest/test_images/data_6106.jpg
# /kaggle/input/jutepest/test_images/data_4583.jpg
# /kaggle/input/jutepest/test_images/data_3502.jpg
# /kaggle/input/jutepest/test_images/data_1605.jpg
# /kaggle/input/jutepest/test_images/data_208.jpeg
# /kaggle/input/jutepest/test_images/data_5995.jpg
# /kaggle/input/jutepest/test_images/data_2151.jpg
# /kaggle/input/jutepest/test_images/data_318.jpg
# /kaggle/input/jutepest/test_images/data_4234.jpg
# /kaggle/input/jutepest/test_images/data_2907.jpg
# /kaggle/input/jutepest/test_images/data_2602.jpg
# /kaggle/input/jutepest/test_images/data_4244.jpg
# /kaggle/input/jutepest/test_images/data_3554.jpg
# /kaggle/input/jutepest/test_images/data_485.jpg
# /kaggle/input/jutepest/test_images/data_3754.jpg
# /kaggle/input/jutepest/test_images/data_1674.jpg
# /kaggle/input/jutepest/test_images/data_3854.jpg
# /kaggle/input/jutepest/test_images/data_2216.jpg
# /kaggle/input/jutepest/test_images/data_2898.jpg
# /kaggle/input/jutepest/test_images/data_5407.jpg
# /kaggle/input/jutepest/test_images/data_6451.jpeg
# /kaggle/input/jutepest/test_images/data_4860.jpg
# /kaggle/input/jutepest/test_images/data_5312.jpg
# /kaggle/input/jutepest/test_images/data_3385.jpg
# /kaggle/input/jutepest/test_images/data_6787.jpg
# /kaggle/input/jutepest/test_images/data_3677.jpg
# /kaggle/input/jutepest/test_images/data_898.jpg
# /kaggle/input/jutepest/test_images/data_1567.jpg
# /kaggle/input/jutepest/test_images/data_4580.jpg
# /kaggle/input/jutepest/test_images/data_3533.jpg
# /kaggle/input/jutepest/test_images/data_62.jpg
# /kaggle/input/jutepest/test_images/data_1186.jpg
# /kaggle/input/jutepest/test_images/data_3890.jpg
# /kaggle/input/jutepest/test_images/data_1385.jpg
# /kaggle/input/jutepest/test_images/data_2370.jpg
# /kaggle/input/jutepest/test_images/data_140.jpg
# /kaggle/input/jutepest/test_images/data_2921.jpg
# /kaggle/input/jutepest/test_images/data_3223.jpg
# /kaggle/input/jutepest/test_images/data_6466.jpg
# /kaggle/input/jutepest/test_images/data_1024.jpg
# /kaggle/input/jutepest/test_images/data_5399.jpg
# /kaggle/input/jutepest/test_images/data_2458.jpg
# /kaggle/input/jutepest/test_images/data_4851.jpg
# /kaggle/input/jutepest/test_images/data_5945.jpg
# /kaggle/input/jutepest/test_images/data_1665.jpg
# /kaggle/input/jutepest/test_images/data_6217.jpg
# /kaggle/input/jutepest/test_images/data_2905.jpg
# /kaggle/input/jutepest/test_images/data_3643.jpg
# /kaggle/input/jutepest/test_images/data_525.jpg
# /kaggle/input/jutepest/test_images/data_277.jpg
# /kaggle/input/jutepest/test_images/data_4996.jpg
# /kaggle/input/jutepest/test_images/data_2670.jpg
# /kaggle/input/jutepest/test_images/data_4086.jpg
# /kaggle/input/jutepest/test_images/data_686.jpg
# /kaggle/input/jutepest/test_images/data_5075.jpg
# /kaggle/input/jutepest/test_images/data_4135.jpg
# /kaggle/input/jutepest/test_images/data_2134.jpg
# /kaggle/input/jutepest/test_images/data_3101.jpg
# /kaggle/input/jutepest/test_images/data_4155.jpg
# /kaggle/input/jutepest/test_images/data_2057.jpg
# /kaggle/input/jutepest/test_images/data_6979.jpg
# /kaggle/input/jutepest/test_images/data_5887.jpg
# /kaggle/input/jutepest/test_images/data_5712.jpg
# /kaggle/input/jutepest/test_images/data_5341.jpg
# /kaggle/input/jutepest/test_images/data_5249.jpg
# /kaggle/input/jutepest/test_images/data_6269.jpg
# /kaggle/input/jutepest/test_images/data_4169.jpg
# /kaggle/input/jutepest/test_images/data_6602.jpg
# /kaggle/input/jutepest/test_images/data_530.jpg
# /kaggle/input/jutepest/test_images/data_3257.jpg
# /kaggle/input/jutepest/test_images/data_1327.jpg
# /kaggle/input/jutepest/test_images/data_2534.jpg
# /kaggle/input/jutepest/test_images/data_6228.jpg
# /kaggle/input/jutepest/test_images/data_351.jpg
# /kaggle/input/jutepest/test_images/data_5544.jpg
# /kaggle/input/jutepest/test_images/data_1606.jpg
# /kaggle/input/jutepest/test_images/data_3584.jpg
# /kaggle/input/jutepest/test_images/data_6546.jpg
# /kaggle/input/jutepest/test_images/data_1055.jpg
# /kaggle/input/jutepest/test_images/data_3412.jpg
# /kaggle/input/jutepest/test_images/data_7173.jpg
# /kaggle/input/jutepest/test_images/data_1584.jpg
# /kaggle/input/jutepest/test_images/data_3342.jpg
# /kaggle/input/jutepest/test_images/data_3483.jpg
# /kaggle/input/jutepest/test_images/data_2158.jpg
# /kaggle/input/jutepest/test_images/data_6799.jpg
# /kaggle/input/jutepest/test_images/data_1612.jpg
# /kaggle/input/jutepest/test_images/data_1643.jpg
# /kaggle/input/jutepest/test_images/data_89.jpg
# /kaggle/input/jutepest/test_images/data_3033.jpg
# /kaggle/input/jutepest/test_images/data_5605.jpg
# /kaggle/input/jutepest/test_images/data_3181.jpg
# /kaggle/input/jutepest/test_images/data_3055.jpg
# /kaggle/input/jutepest/test_images/data_230.jpg
# /kaggle/input/jutepest/test_images/data_5631.jpg
# /kaggle/input/jutepest/test_images/data_3348.jpg
# /kaggle/input/jutepest/test_images/data_5251.jpg
# /kaggle/input/jutepest/test_images/data_628.jpg
# /kaggle/input/jutepest/test_images/data_657.jpg
# /kaggle/input/jutepest/test_images/data_5963.jpg
# /kaggle/input/jutepest/test_images/data_509.jpg
# /kaggle/input/jutepest/test_images/data_6597.jpg
# /kaggle/input/jutepest/test_images/data_4243.jpg
# /kaggle/input/jutepest/test_images/data_569.jpg
# /kaggle/input/jutepest/test_images/data_6774.jpg
# /kaggle/input/jutepest/test_images/data_6858.jpg
# /kaggle/input/jutepest/test_images/data_343.jpg
# /kaggle/input/jutepest/test_images/data_5392.jpg
# /kaggle/input/jutepest/test_images/data_4845.jpg
# /kaggle/input/jutepest/test_images/data_3274.jpg
# /kaggle/input/jutepest/test_images/data_6937.jpg
# /kaggle/input/jutepest/test_images/data_1997.jpg
# /kaggle/input/jutepest/test_images/data_3368.jpg
# /kaggle/input/jutepest/test_images/data_4551.jpg
# /kaggle/input/jutepest/test_images/data_213.jpg
# /kaggle/input/jutepest/test_images/data_6300.jpg
# /kaggle/input/jutepest/test_images/data_6688.jpg
# /kaggle/input/jutepest/test_images/data_4441.jpg
# /kaggle/input/jutepest/test_images/data_2407.jpg
# /kaggle/input/jutepest/test_images/data_748.jpg
# /kaggle/input/jutepest/test_images/data_6783.jpg
# /kaggle/input/jutepest/test_images/data_1560.jpg
# /kaggle/input/jutepest/test_images/data_5682.jpg
# /kaggle/input/jutepest/test_images/data_1770.jpg
# /kaggle/input/jutepest/test_images/data_5382.jpg
# /kaggle/input/jutepest/test_images/data_4411.jpg
# /kaggle/input/jutepest/test_images/data_606.jpg
# /kaggle/input/jutepest/test_images/data_1252.jpg
# /kaggle/input/jutepest/test_images/data_2276.jpg
# /kaggle/input/jutepest/test_images/data_1239.jpg
# /kaggle/input/jutepest/test_images/data_2381.jpg
# /kaggle/input/jutepest/test_images/data_2833.jpg
# /kaggle/input/jutepest/test_images/data_1122.jpg
# /kaggle/input/jutepest/test_images/data_5693.jpg
# /kaggle/input/jutepest/test_images/data_5431.jpg
# /kaggle/input/jutepest/test_images/data_2522.jpg
# /kaggle/input/jutepest/test_images/data_2541.jpg
# /kaggle/input/jutepest/test_images/data_5507.jpg
# /kaggle/input/jutepest/test_images/data_5125.jpg
# /kaggle/input/jutepest/test_images/data_4556.jpg
# /kaggle/input/jutepest/test_images/data_2706.jpg
# /kaggle/input/jutepest/test_images/data_7072.jpg
# /kaggle/input/jutepest/test_images/data_5903.jpg
# /kaggle/input/jutepest/test_images/data_943.jpg
# /kaggle/input/jutepest/test_images/data_7054.jpg
# /kaggle/input/jutepest/test_images/data_4950.jpg
# /kaggle/input/jutepest/test_images/data_5371.jpg
# /kaggle/input/jutepest/test_images/data_5132.jpg
# /kaggle/input/jutepest/test_images/data_5008.jpg
# /kaggle/input/jutepest/test_images/data_1935.jpg
# /kaggle/input/jutepest/test_images/data_1708.jpg
# /kaggle/input/jutepest/test_images/data_6188.jpg
# /kaggle/input/jutepest/test_images/data_389.jpg
# /kaggle/input/jutepest/test_images/data_436.jpg
# /kaggle/input/jutepest/test_images/data_6907.jpg
# /kaggle/input/jutepest/test_images/data_3871.jpg
# /kaggle/input/jutepest/test_images/data_5635.jpg
# /kaggle/input/jutepest/test_images/data_4694.jpg
# /kaggle/input/jutepest/test_images/data_1159.jpg
# /kaggle/input/jutepest/test_images/data_1407.jpg
# /kaggle/input/jutepest/test_images/data_979.jpg
# /kaggle/input/jutepest/test_images/data_7084.jpg
# /kaggle/input/jutepest/test_images/data_6132.jpg
# /kaggle/input/jutepest/test_images/data_4013.jpg
# /kaggle/input/jutepest/test_images/data_5766.jpg
# /kaggle/input/jutepest/test_images/data_4953.jpg
# /kaggle/input/jutepest/test_images/data_2092.jpg
# /kaggle/input/jutepest/test_images/data_411.jpg
# /kaggle/input/jutepest/test_images/data_4012.jpg
# /kaggle/input/jutepest/test_images/data_634.jpg
# /kaggle/input/jutepest/test_images/data_1299.jpg
# /kaggle/input/jutepest/test_images/data_4892.jpg
# /kaggle/input/jutepest/test_images/data_7172.jpg
# /kaggle/input/jutepest/test_images/data_3588.jpg
# /kaggle/input/jutepest/test_images/data_4523.jpg
# /kaggle/input/jutepest/test_images/data_3491.jpg
# /kaggle/input/jutepest/test_images/data_2497.jpg
# /kaggle/input/jutepest/test_images/data_2190.jpg
# /kaggle/input/jutepest/test_images/data_7032.jpg
# /kaggle/input/jutepest/test_images/data_2666.jpg
# /kaggle/input/jutepest/test_images/data_1246.jpg
# /kaggle/input/jutepest/test_images/data_1405.jpg
# /kaggle/input/jutepest/test_images/data_7050.jpg
# /kaggle/input/jutepest/test_images/data_5559.jpg
# /kaggle/input/jutepest/test_images/data_6158.jpg
# /kaggle/input/jutepest/test_images/data_2282.jpg
# /kaggle/input/jutepest/test_images/data_224.jpg
# /kaggle/input/jutepest/test_images/data_5184.jpg
# /kaggle/input/jutepest/test_images/data_5970.jpg
# /kaggle/input/jutepest/test_images/data_4515.jpg
# /kaggle/input/jutepest/test_images/data_245.jpg
# /kaggle/input/jutepest/test_images/data_5564.jpg
# /kaggle/input/jutepest/test_images/data_5604.jpg
# /kaggle/input/jutepest/test_images/data_268.jpg
# /kaggle/input/jutepest/test_images/data_3815.jpg
# /kaggle/input/jutepest/test_images/data_4482.jpg
# /kaggle/input/jutepest/test_images/data_1437.jpg
# /kaggle/input/jutepest/test_images/data_2070.jpg
# /kaggle/input/jutepest/test_images/data_5028.jpg
# /kaggle/input/jutepest/test_images/data_5676.jpg
# /kaggle/input/jutepest/test_images/data_3170.jpg
# /kaggle/input/jutepest/test_images/data_3465.jpg
# /kaggle/input/jutepest/test_images/data_3557.jpg
# /kaggle/input/jutepest/test_images/data_3714.jpg
# /kaggle/input/jutepest/test_images/data_2083.jpg
# /kaggle/input/jutepest/test_images/data_5073.jpg
# /kaggle/input/jutepest/test_images/data_629.jpg
# /kaggle/input/jutepest/test_images/data_4494.jpg
# /kaggle/input/jutepest/test_images/data_3820.jpg
# /kaggle/input/jutepest/test_images/data_4866.jpg
# /kaggle/input/jutepest/test_images/data_199.jpg
# /kaggle/input/jutepest/test_images/data_6024.jpg
# /kaggle/input/jutepest/test_images/data_4744.jpg
# /kaggle/input/jutepest/test_images/data_7180.jpg
# /kaggle/input/jutepest/test_images/data_7135.jpg
# /kaggle/input/jutepest/test_images/data_4483.jpg
# /kaggle/input/jutepest/test_images/data_6285.jpg
# /kaggle/input/jutepest/test_images/data_2936.jpg
# /kaggle/input/jutepest/test_images/data_6455.jpg
# /kaggle/input/jutepest/test_images/data_5792.jpg
# /kaggle/input/jutepest/test_images/data_2000.jpg
# /kaggle/input/jutepest/test_images/data_2553.jpg
# /kaggle/input/jutepest/test_images/data_7167.jpg
# /kaggle/input/jutepest/test_images/data_2885.jpg
# /kaggle/input/jutepest/test_images/data_2520.jpg
# /kaggle/input/jutepest/test_images/data_5935.jpg
# /kaggle/input/jutepest/test_images/data_1798.jpg
# /kaggle/input/jutepest/test_images/data_4569.jpg
# /kaggle/input/jutepest/test_images/data_1083.jpg
# /kaggle/input/jutepest/test_images/data_6692.jpg
# /kaggle/input/jutepest/test_images/data_5834.jpg
# /kaggle/input/jutepest/test_images/data_3995.jpg
# /kaggle/input/jutepest/test_images/data_4934.jpg
# /kaggle/input/jutepest/test_images/data_911.jpg
# /kaggle/input/jutepest/test_images/data_2081.jpg
# /kaggle/input/jutepest/test_images/data_3217.jpg
# /kaggle/input/jutepest/test_images/data_6251.jpg
# /kaggle/input/jutepest/test_images/data_510.jpg
# /kaggle/input/jutepest/test_images/data_6528.jpg
# /kaggle/input/jutepest/test_images/data_3565.jpg
# /kaggle/input/jutepest/test_images/data_398.jpg
# /kaggle/input/jutepest/test_images/data_4505.jpg
# /kaggle/input/jutepest/test_images/data_6412.jpg
# /kaggle/input/jutepest/test_images/data_6162.jpg
# /kaggle/input/jutepest/test_images/data_2371.jpg
# /kaggle/input/jutepest/test_images/data_3866.jpg
# /kaggle/input/jutepest/test_images/data_2228.jpg
# /kaggle/input/jutepest/test_images/data_4216.jpg
# /kaggle/input/jutepest/test_images/data_4206.jpg
# /kaggle/input/jutepest/test_images/data_6487.jpg
# /kaggle/input/jutepest/test_images/data_513.jpg
# /kaggle/input/jutepest/test_images/data_4821.jpg
# /kaggle/input/jutepest/test_images/data_1141.jpg
# /kaggle/input/jutepest/test_images/data_1594.jpg
# /kaggle/input/jutepest/test_images/data_4066.jpg
# /kaggle/input/jutepest/test_images/data_4753.jpg
# /kaggle/input/jutepest/test_images/data_540.jpg
# /kaggle/input/jutepest/test_images/data_1270.jpg
# /kaggle/input/jutepest/test_images/data_2844.jpg
# /kaggle/input/jutepest/test_images/data_2363.jpg
# /kaggle/input/jutepest/test_images/data_2234.jpg
# /kaggle/input/jutepest/test_images/data_7198.jpg
# /kaggle/input/jutepest/test_images/data_428.jpg
# /kaggle/input/jutepest/test_images/data_1792.jpg
# /kaggle/input/jutepest/test_images/data_3787.jpg
# /kaggle/input/jutepest/test_images/data_4598.jpg
# /kaggle/input/jutepest/test_images/data_1255.jpg
# /kaggle/input/jutepest/test_images/data_2884.jpg
# /kaggle/input/jutepest/test_images/data_2383.jpg
# /kaggle/input/jutepest/test_images/data_5300.jpg
# /kaggle/input/jutepest/test_images/data_3351.jpg
# /kaggle/input/jutepest/test_images/data_3826.jpg
# /kaggle/input/jutepest/test_images/data_5807.jpg
# /kaggle/input/jutepest/test_images/data_6128.jpg
# /kaggle/input/jutepest/test_images/data_1516.jpg
# /kaggle/input/jutepest/test_images/data_4344.jpg
# /kaggle/input/jutepest/test_images/data_2571.jpg
# /kaggle/input/jutepest/test_images/data_5467.jpg
# /kaggle/input/jutepest/test_images/data_1808.jpg
# /kaggle/input/jutepest/test_images/data_5752.jpg
# /kaggle/input/jutepest/test_images/data_1208.jpg
# /kaggle/input/jutepest/test_images/data_6615.jpg
# /kaggle/input/jutepest/test_images/data_1895.jpg
# /kaggle/input/jutepest/test_images/data_2129.jpg
# /kaggle/input/jutepest/test_images/data_1334.jpg
# /kaggle/input/jutepest/test_images/data_3696.jpg
# /kaggle/input/jutepest/test_images/data_6282.jpg
# /kaggle/input/jutepest/test_images/data_6071.jpg
# /kaggle/input/jutepest/test_images/data_1032.jpg
# /kaggle/input/jutepest/test_images/data_2608.jpg
# /kaggle/input/jutepest/test_images/data_500.jpg
# /kaggle/input/jutepest/test_images/data_1730.jpg
# /kaggle/input/jutepest/test_images/data_7131.jpg
# /kaggle/input/jutepest/test_images/data_4130.jpg
# /kaggle/input/jutepest/test_images/data_5078.jpg
# /kaggle/input/jutepest/test_images/data_3504.jpg
# /kaggle/input/jutepest/test_images/data_5971.jpg
# /kaggle/input/jutepest/test_images/data_7104.jpg
# /kaggle/input/jutepest/test_images/data_734.jpg
# /kaggle/input/jutepest/test_images/data_220.jpg
# /kaggle/input/jutepest/test_images/data_2003.jpg
# /kaggle/input/xception/pytorch/xception/1/best_model.pth

# %%
# Load and preview the dataset
train = pd.read_csv('/kaggle/input/jutepest/train.csv')
train.head()
# Out:
#         filename             class
# 0   data_813.jpg  Jute Stem Weevil
# 1  data_6274.jpg          Mealybug
# 2  data_2317.jpg       Black Hairy
# 3  data_2124.jpg           Termite
# 4  data_5974.jpg        Jute Aphid

# %%
# Encode class labels to integers
label_encoder = LabelEncoder()
train['class'] = label_encoder.fit_transform(train['class'])

# %%
# Define the image transformation
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),
    transforms.ToTensor(),
])

# %%
# Define custom dataset class
class JutePestDataset(Dataset):
    def __init__(self, dataframe, img_dir, transform=None):
        self.dataframe = dataframe
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = os.path.join(self.img_dir, self.dataframe.iloc[idx, 0])
        image = Image.open(img_name).convert('RGB')

        if self.transform:
            image = self.transform(image)

        label = self.dataframe.iloc[idx, 1]
        label = torch.tensor(label, dtype=torch.long)

        return image, label

# %%
# Create dataset and split into training and validation sets
train_dir = '/kaggle/input/jutepest/train_images/'
dataset = JutePestDataset(train, train_dir, transform)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# %%
# Display a sample image
plt.imshow(torch.permute(dataset[4][0], (1, 2, 0)))
plt.show()

# %%
# Create DataLoader instances
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### ResNet

# %%
# Define a custom model using Xception from timm
class CustomXception(nn.Module):
    def __init__(self, num_classes):
        super(CustomXception, self).__init__()
        self.model = timm.create_model('xception', pretrained=False, num_classes=num_classes)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.model(x)
        x = self.dropout(x)
        return x

# %%
# Initialize the model, loss function, optimizer, and learning rate scheduler
model = CustomXception(num_classes=17)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-4)  # L2 regularization
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.75)
# Out:
# /opt/conda/lib/python3.10/site-packages/timm/models/_factory.py:117: UserWarning: Mapping deprecated model name xception to current legacy_xception.
#   model = create_fn(

# %%
# Print model summary
from torchinfo import summary
summary(model, (32, 3, 224, 224))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CustomXception                                [32, 17]                  --
# ├─Xception: 1-1                               [32, 17]                  --
# │    └─Conv2d: 2-1                            [32, 32, 111, 111]        864
# │    └─BatchNorm2d: 2-2                       [32, 32, 111, 111]        64
# │    └─ReLU: 2-3                              [32, 32, 111, 111]        --
# │    └─Conv2d: 2-4                            [32, 64, 109, 109]        18,432
# │    └─BatchNorm2d: 2-5                       [32, 64, 109, 109]        128
# │    └─ReLU: 2-6                              [32, 64, 109, 109]        --
# │    └─Block: 2-7                             [32, 128, 55, 55]         --
# │    │    └─Sequential: 3-1                   [32, 128, 55, 55]         26,816
# │    │    └─Conv2d: 3-2                       [32, 128, 55, 55]         8,192
# │    │    └─BatchNorm2d: 3-3                  [32, 128, 55, 55]         256
# │    └─Block: 2-8                             [32, 256, 28, 28]         --
# │    │    └─Sequential: 3-4                   [32, 256, 28, 28]         102,784
# │    │    └─Conv2d: 3-5                       [32, 256, 28, 28]         32,768
# │    │    └─BatchNorm2d: 3-6                  [32, 256, 28, 28]         512
# │    └─Block: 2-9                             [32, 728, 14, 14]         --
# │    │    └─Sequential: 3-7                   [32, 728, 14, 14]         728,120
# │    │    └─Conv2d: 3-8                       [32, 728, 14, 14]         186,368
# │    │    └─BatchNorm2d: 3-9                  [32, 728, 14, 14]         1,456
# │    └─Block: 2-10                            [32, 728, 14, 14]         --
# │    │    └─Sequential: 3-10                  [32, 728, 14, 14]         1,613,976
# │    └─Block: 2-11                            [32, 728, 14, 14]         --
# │    │    └─Sequential: 3-11                  [32, 728, 14, 14]         1,613,976
# │    └─Block: 2-12                            [32, 728, 14, 14]         --
# │    │    └─Sequential: 3-12                  [32, 728, 14, 14]         1,613,976
# │    └─Block: 2-13                            [32, 728, 14, 14]         --
# │    │    └─Sequential: 3-13                  [32, 728, 14, 14]         1,613,976
# │    └─Block: 2-14                            [32, 728, 14, 14]         --
# │    │    └─Sequential: 3-14                  [32, 728, 14, 14]         1,613,976
# │    └─Block: 2-15                            [32, 728, 14, 14]         --
# │    │    └─Sequential: 3-15                  [32, 728, 14, 14]         1,613,976
# │    └─Block: 2-16                            [32, 728, 14, 14]         --
# │    │    └─Sequential: 3-16                  [32, 728, 14, 14]         1,613,976
# │    └─Block: 2-17                            [32, 728, 14, 14]         --
# │    │    └─Sequential: 3-17                  [32, 728, 14, 14]         1,613,976
# │    └─Block: 2-18                            [32, 1024, 7, 7]          --
# │    │    └─Sequential: 3-18                  [32, 1024, 7, 7]          1,292,064
# │    │    └─Conv2d: 3-19                      [32, 1024, 7, 7]          745,472
# │    │    └─BatchNorm2d: 3-20                 [32, 1024, 7, 7]          2,048
# │    └─SeparableConv2d: 2-19                  [32, 1536, 7, 7]          --
# │    │    └─Conv2d: 3-21                      [32, 1024, 7, 7]          9,216
# │    │    └─Conv2d: 3-22                      [32, 1536, 7, 7]          1,572,864
# │    └─BatchNorm2d: 2-20                      [32, 1536, 7, 7]          3,072
# │    └─ReLU: 2-21                             [32, 1536, 7, 7]          --
# │    └─SeparableConv2d: 2-22                  [32, 2048, 7, 7]          --
# │    │    └─Conv2d: 3-23                      [32, 1536, 7, 7]          13,824
# │    │    └─Conv2d: 3-24                      [32, 2048, 7, 7]          3,145,728
# │    └─BatchNorm2d: 2-23                      [32, 2048, 7, 7]          4,096
# │    └─ReLU: 2-24                             [32, 2048, 7, 7]          --
# │    └─SelectAdaptivePool2d: 2-25             [32, 2048]                --
# │    │    └─AdaptiveAvgPool2d: 3-25           [32, 2048, 1, 1]          --
# │    │    └─Flatten: 3-26                     [32, 2048]                --
# │    └─Linear: 2-26                           [32, 17]                  34,833
# ├─Dropout: 1-2                                [32, 17]                  --
# ===============================================================================================
# Total params: 20,841,785
# Trainable params: 20,841,785
# Non-trainable params: 0
# Total mult-adds (G): 145.63
# ===============================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 8005.41
# Params size (MB): 83.37
# Estimated Total Size (MB): 8108.04
# ===============================================================================================

# %%
# Determine the device to use
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
torch.cuda.empty_cache()
model.to(device)
# Out:
# CustomXception(
#   (model): Xception(
#     (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act1): ReLU(inplace=True)
#     (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act2): ReLU(inplace=True)
#     (block1): Block(
#       (skip): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (skipbn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (rep): Sequential(
#         (0): SeparableConv2d(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#           (pointwise): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): SeparableConv2d(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (pointwise): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       )
#     )
#     (block2): Block(
#       (skip): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (skipbn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#           (pointwise): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (pointwise): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       )
#     )
#     (block3): Block(
#       (skip): Conv2d(256, 728, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (skipbn): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#           (pointwise): Conv2d(256, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       )
#     )
#     (block4): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block5): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block6): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block7): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block8): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block9): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block10): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block11): Block(
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): ReLU(inplace=True)
#         (7): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (8): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block12): Block(
#       (skip): Conv2d(728, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (skipbn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (rep): Sequential(
#         (0): ReLU()
#         (1): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 728, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (2): BatchNorm2d(728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (3): ReLU(inplace=True)
#         (4): SeparableConv2d(
#           (conv1): Conv2d(728, 728, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=728, bias=False)
#           (pointwise): Conv2d(728, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       )
#     )
#     (conv3): SeparableConv2d(
#       (conv1): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024, bias=False)
#       (pointwise): Conv2d(1024, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn3): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act3): ReLU(inplace=True)
#     (conv4): SeparableConv2d(
#       (conv1): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#       (pointwise): Conv2d(1536, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (bn4): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act4): ReLU(inplace=True)
#     (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#     (fc): Linear(in_features=2048, out_features=17, bias=True)
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Fungsi untuk menghitung akurasi
def calc_accuracy(true, pred):
    pred = F.softmax(pred, dim=1)
    acc = (true == pred.argmax(dim=1)).float().mean().item()
    return round(acc * 100, 2)

# %%
# Fungsi untuk menghitung F1 Score
def calc_f1_score(true, pred):
    pred = F.softmax(pred, dim=1).argmax(dim=1)
    true = true.cpu().numpy()
    pred = pred.cpu().numpy()
    return f1_score(true, pred, average='weighted')

# %% [markdown]
# ## Melanjutkan Epoch Sebelumnya

# %%
checkpoint_path = ''

# Check if checkpoint exists
if os.path.exists(checkpoint_path) and checkpoint_path:
    # Load the checkpoint
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    start_epoch = checkpoint['epoch']
    best_val_loss = checkpoint['best_val_loss']
    patience_counter = checkpoint['patience_counter']
    train_loss = checkpoint['train_loss']
    train_accuracy = checkpoint['train_accuracy']
    train_f1_score = checkpoint['train_f1_score']
    val_loss = checkpoint['val_loss']
    val_accuracy = checkpoint['val_accuracy']
    val_f1_score = checkpoint['val_f1_score']
    print(f"Checkpoint loaded, starting from epoch {start_epoch}")
else:
    # Initialize training and validation statistics
    start_epoch = 0
    best_val_loss = np.inf
    patience_counter = 0
    train_loss = []
    train_accuracy = []
    train_f1_score = []
    val_loss = []
    val_accuracy = []
    val_f1_score = []
    print("No checkpoint found, starting from scratch")
# Out:
# No checkpoint found, starting from scratch

# %% [markdown]
# ## Training

# %%
# Initialize training and validation statistics
epochs = 100
patience = 6

# %%
# Training loop
for epoch in range(start_epoch, epochs):
    start_time = time.time()
    train_epoch_loss = []
    train_epoch_accuracy = []
    train_epoch_f1_score = []
    val_epoch_loss = []
    val_epoch_accuracy = []
    val_epoch_f1_score = []

    model.train()
    with tqdm(total=len(train_loader), desc=f"Epoch {epoch + 1}/{epochs}", unit='batch') as pbar:
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            preds = model(images)
            acc = calc_accuracy(labels, preds)
            f1 = calc_f1_score(labels, preds)
            loss = criterion(preds, labels)
            loss.backward()
            optimizer.step()

            train_epoch_loss.append(loss.item())
            train_epoch_accuracy.append(acc)
            train_epoch_f1_score.append(f1)

            pbar.set_postfix({'Training Loss': np.mean(train_epoch_loss), 'Training Accuracy': np.mean(train_epoch_accuracy), 'Training F1 Score': np.mean(train_epoch_f1_score)})
            pbar.update(1)

    model.eval()
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)
            preds = model(images)
            acc = calc_accuracy(labels, preds)
            f1 = calc_f1_score(labels, preds)
            loss = criterion(preds, labels)

            val_epoch_loss.append(loss.item())
            val_epoch_accuracy.append(acc)
            val_epoch_f1_score.append(f1)

    train_epoch_loss = np.mean(train_epoch_loss)
    train_epoch_accuracy = np.mean(train_epoch_accuracy)
    train_epoch_f1_score = np.mean(train_epoch_f1_score)
    val_epoch_loss = np.mean(val_epoch_loss)
    val_epoch_accuracy = np.mean(val_epoch_accuracy)
    val_epoch_f1_score = np.mean(val_epoch_f1_score)

    train_loss.append(train_epoch_loss)
    train_accuracy.append(train_epoch_accuracy)
    train_f1_score.append(train_epoch_f1_score)
    val_loss.append(val_epoch_loss)
    val_accuracy.append(val_epoch_accuracy)
    val_f1_score.append(val_epoch_f1_score)

    end_time = time.time()
    epoch_duration = end_time - start_time

    print(f"Epoch {epoch + 1}/{epochs}, Training Loss: {train_epoch_loss:.4f}, Training Accuracy: {train_epoch_accuracy:.2f}%, Training F1 Score: {train_epoch_f1_score:.2f}")
    print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_accuracy:.2f}%, Validation F1 Score: {val_epoch_f1_score:.2f}, Epoch Duration: {epoch_duration:.2f} seconds")

    # Save the model and optimizer state every 10 epochs
    if (epoch + 1) % 10 == 0 or (epoch + 1) == epochs:
        checkpoint = {
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_loss': best_val_loss,
            'patience_counter': patience_counter,
            'train_loss': train_loss,
            'train_accuracy': train_accuracy,
            'train_f1_score': train_f1_score,
            'val_loss': val_loss,
            'val_accuracy': val_accuracy,
            'val_f1_score': val_f1_score
        }
        torch.save(checkpoint, f'checkpoint_epoch_{epoch + 1}.pth')
        print(f'Model saved at epoch {epoch + 1}')

    if val_epoch_loss < best_val_loss:
        best_val_loss = val_epoch_loss
        patience_counter = 0
        checkpoint_best = {
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_loss': best_val_loss,
            'patience_counter': patience_counter,
            'train_loss': train_loss,
            'train_accuracy': train_accuracy,
            'train_f1_score': train_f1_score,
            'val_loss': val_loss,
            'val_accuracy': val_accuracy,
            'val_f1_score': val_f1_score
        }
        torch.save(checkpoint_best, 'checkpoint_best.pth')
        torch.save(model.state_dict(), 'best_model.pth')
        print('Best model saved')
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("Early stopping triggered")
            checkpoint = {
                'epoch': epoch + 1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'best_val_loss': best_val_loss,
                'patience_counter': patience_counter,
                'train_loss': train_loss,
                'train_accuracy': train_accuracy,
                'train_f1_score': train_f1_score,
                'val_loss': val_loss,
                'val_accuracy': val_accuracy,
                'val_f1_score': val_f1_score
            }
            torch.save(checkpoint, f'checkpoint_epoch_{epoch + 1}.pth')
            print(f'Model saved at epoch {epoch + 1} due to early stopping')
            break

    lr_scheduler.step()
# Out:
# Epoch 1/100:   8%|▊         | 12/154 [00:08<01:38,  1.45batch/s, Training Loss=2.83, Training Accuracy=7.81, Training F1 Score=0.0592]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[82], line 25
#      22 loss.backward()
#      23 optimizer.step()
# ---> 25 train_epoch_loss.append(loss.item())
#      26 train_epoch_accuracy.append(acc)
#      27 train_epoch_f1_score.append(f1)
#
# KeyboardInterrupt:

# %%
# Save the checkpoint at the last epoch if not already saved
if (epoch + 1) % 10 != 0 and (epoch + 1) != epochs:
    checkpoint = {
        'epoch': epoch + 1,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'best_val_loss': best_val_loss,
        'patience_counter': patience_counter
    }
    torch.save(checkpoint, f'checkpoint_epoch_{epoch + 1}.pth')
    print(f'Model saved at the final epoch {epoch + 1}')

# %%
# Plotting the loss, accuracy, and F1 score
actual_epochs = len(train_loss)

epochs_range = range(1, actual_epochs + 1)

plt.figure(figsize=(18, 6))

# Plot training & validation loss values
plt.subplot(1, 3, 1)
plt.plot(epochs_range, train_loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

# Plot training & validation accuracy values
plt.subplot(1, 3, 2)
plt.plot(epochs_range, train_accuracy, label='Training Accuracy')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='upper left')

# Plot training & validation F1 score values
plt.subplot(1, 3, 3)
plt.plot(epochs_range, train_f1_score, label='Training F1 Score')
plt.plot(epochs_range, val_f1_score, label='Validation F1 Score')
plt.title('F1 Score')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Define the test dataset class
class TestJutePestDataset(Dataset):
    def __init__(self, dataframe, img_dir, transform=None):
        self.dataframe = dataframe
        self.img_dir = img_dir
        self.transform = transform
    
    def __len__(self):
        return len(self.dataframe)
    
    def __getitem__(self, idx):
        img_name = os.path.join(self.img_dir, self.dataframe.iloc[idx, 1])
        image = Image.open(img_name).convert('RGB')
        
        if self.transform:
            image = self.transform(image)
        
        return image

# %%
# Load and prepare test dataset
test_dir = '/kaggle/input/jutepest/test_images/'
test_csv = pd.read_csv('/kaggle/input/jutepest/test.csv')
test_dataset = TestJutePestDataset(test_csv, test_dir, transform)
plt.imshow(torch.permute(test_dataset[0], (1, 2, 0)))
plt.show()

# %%
# Create DataLoader for test dataset
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Function for making predictions
def predict(model, test_loader):
    model.eval()
    predictions = []
    
    with torch.no_grad():
        for images in test_loader:
            images = images.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            predictions.extend(predicted.cpu().numpy())
    
    return predictions

# %%
# Make predictions on test dataset
predictions = predict(model, test_loader)
predicted_labels = label_encoder.inverse_transform(predictions)

# %%
# Prepare submission file
test = pd.read_csv('/kaggle/input/jutepest/test.csv')
sub = pd.concat([test.id, pd.DataFrame(predicted_labels, columns=['class'])], axis=1)
sub.set_index('id', inplace=True)
sub.to_csv("submission_xception.csv")
sub
